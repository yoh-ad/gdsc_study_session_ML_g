# %%
import numpy as np
array = [31,54,53,64,45]
numpy_array = np.array(array)
mean_np = np.mean(numpy_array)
max_np = np.max(numpy_array)
sum_np = np.sum(numpy_array)
print(f"Original array: {array}")
print(f"mean:{mean_np}")
print(f"max:  {max_np}")
print(f"sum: {sum_np}")
# Out:
# Original array: [31, 54, 53, 64, 45]
# mean:49.4
# max:  64
# sum: 247
